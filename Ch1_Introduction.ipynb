# %% [markdown]
# # 1.1 Example: Polynomial Curve Fitting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 100)
y = np.sin(2*np.pi*x)
plt.figure()
plt.plot(x,y)

# %%
def pow_of_x(x, M):
    N = x.shape[0]
    z = np.zeros([N, M])
    for i in range(M):
